# %%
import numpy as np

# %%
# Creating a scalar using numpy
a = np.array(4)

# %%
a
# this is a OD tensor, tensor and nD dimensional array are same
# there is just one number, we have a numpy function
# Out:
# array(4)

# %%
a.ndim
# we can see the dimension is zero
# Out:
# 0
