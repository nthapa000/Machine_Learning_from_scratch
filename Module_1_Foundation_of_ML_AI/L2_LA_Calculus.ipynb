# %%
import numpy as np

# %%
v1 = np.array([1, 0])
v2 = np.array([2, 0])

# %%
# checking for the linear dependecy by computing the rank of the matrix formed by the vectors
matrix = np.vstack([v1,v2])
# row wise stack
rank = np.linalg.matrix_rank(matrix)
# print(rank)
is_linearly_dependent = rank < min(matrix.shape)
# print("hello")
print(is_linearly_dependent)
# Out:
# True

# %% [markdown]
# Euclidean Norm"

# %%
v = np.array([3,4])
v
# Out:
# array([3, 4])

# %%
euclidean_norm = np.linalg.norm(v)
print(euclidean_norm)
# Out:
# 5.0

# %% [markdown]
# Visualizing Vectors

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.quiver(0, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1, color='r', label='v1')
ax.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1, color='b', label='v2')
ax.set_xlim(-1,3)
ax.set_ylim(-1,3)
ax.set_aspect('equal')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Linear Regression

# %%
np.random.seed(0)
X = 2*np.random.rand(100,1)
y = 3 + 4 * X + np.random.randn(100,1)

# add a column of ones to X to account for the bias_term
X_b = np.c_[np.ones((100,1)),X]

# Compute the optimal parameters using the normal equation
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print(theta_best)
# Out:
# [[3.22215108]
#  [3.96846751]]

# %% [markdown]
# Visualization of Vectors using Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the vectors
a = np.array([2, 3])
b = np.array([4, 1])

# Create the plot
plt.figure(figsize=(5, 5))

# Draw x-axis and y-axis
plt.axvline(x=0, color='grey', lw=1)
plt.axhline(y=0, color='grey', lw=1)

# Add grid
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Set axis limits
plt.xlim(-1, 5)
plt.ylim(-1, 5)

# Plot vector a
plt.quiver(
    0, 0, a[0], a[1],
    angles='xy',
    scale_units='xy',
    scale=1,
    color='r',
    label='a'
)

# Plot vector b
plt.quiver(
    0, 0, b[0], b[1],
    angles='xy',
    scale_units='xy',
    scale=1,
    color='b',
    label='b'
)

# Add legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# Linear Regression

# %%
np.random.seed(0)
X = 2 * np.random.rand(100,1)
y = 3 + 4 * X + np.random.randn(100,1)

# add a column of ones to X to account for the bias term 
X_b = np.c_[np.ones((100,1)),X]

# normal equation used to find the optimal theta
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print(theta_best)
# Out:
# [[3.22215108]
#  [3.96846751]]

# %% [markdown]
# Gram Schimidt Process

# %%
import numpy as np

def gram_schmidt(vectors):
    basis = []

    for v in vectors:
        # Remove projections onto existing basis vectors
        w = v - sum(np.dot(v, b) * b for b in basis)

        # Check if vector is not near zero
        if np.linalg.norm(w) > 1e-10:
            basis.append(w / np.linalg.norm(w))

    return np.array(basis)

vectors = np.array([[1, 1], [1, -1]])

orthonormal_basis = gram_schmidt(vectors)

print(orthonormal_basis)
# Out:
# [[ 0.70710678  0.70710678]
#  [ 0.70710678 -0.70710678]]

# %% [markdown]
# How to compute the eigenvalues and eigenvectors of a matrix using NumPy and visualize them using Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([[2, 1],
              [1, 2]])

eigenvalues, eigenvectors = np.linalg.eig(A)

print("Eigenvalues:", eigenvalues)
print("Eigenvectors:\n", eigenvectors)

# origins for 2 arrows
X = [0, 0]
Y = [0, 0]

# vector components
U = eigenvectors[0, :]
V = eigenvectors[1, :]

plt.quiver(X, Y, U, V,
           color=['r', 'b'],
           scale=3)

plt.xlim(-1, 1)
plt.ylim(-1, 1)

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.grid(color='gray', linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Eigenvalues: [3. 1.]
# Eigenvectors:
#  [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
# LU Decomposition

# %%
from scipy.linalg import lu

# %%
A = np.array([[1, 2],
              [3, 4]])

# perform LU decomposition
P, L, U = lu(A)
P
# Out:
# array([[0., 1.],
#        [1., 0.]])

# %%
L
# Out:
# array([[1.        , 0.        ],
#        [0.33333333, 1.        ]])

# %%
U
# Out:
# array([[3.        , 4.        ],
#        [0.        , 0.66666667]])

# %%
print("Product of PLU: ", P@L@U)
# Out:
# Product of PLU:  [[1. 2.]
#  [3. 4.]]

# %% [markdown]
# SVD

# %%
U, Sigma, VT = np.linalg.svd(A)
U
# Out:
# array([[-0.40455358, -0.9145143 ],
#        [-0.9145143 ,  0.40455358]])

# %% [markdown]
# PCA

# %%
from sklearn.decomposition import PCA
np.random.seed(0)
X = np.random.randn(100,2)

pca = PCA(n_components=1)
X_pca = pca.fit_transform(X)

X_pca
# Out:
# array([[ 1.2334883 ],
#        [-0.51779257],
#        [ 2.16221372],
#        [ 0.93082409],
#        [-0.24534285],
#        [-0.69221634],
#        [ 0.61383904],
#        [ 0.2333584 ],
#        [ 1.39286716],
#        [ 0.86068707],
#        [-2.32652924],
#        [ 1.22662461],
#        [ 2.77276388],
#        [ 0.23976073],
#        [ 0.39357392],
#        [-0.02182176],
#        [ 0.60667998],
#        [-0.28193155],
#        [ 0.31924006],
#        [-0.03094562],
#        [ 0.13503663],
#        [-2.45659791],
#        [-0.04390551],
#        [-1.37745937],
#        [-1.05322052],
#        [-0.85548561],
#        [ 0.41185033],
#        [-0.19707962],
#        [-0.04500323],
#        [-0.18854123],
#        [-0.22057527],
#        [ 0.50901261],
#        [ 0.47556021],
#        [-1.48151302],
#        [-0.65882045],
#        [ 0.58415329],
#        [ 1.74642491],
#        [ 0.82697393],
#        [-0.24210587],
#        [-0.19164886],
#        [-1.38419812],
# ...

# %% [markdown]
# Gradient Descent

# %%
def gradient_descent(gradient, start, learn_rate, n_iter):
    vector = start
    for _ in range(n_iter):
        diff = -learn_rate * gradient(vector)
        vector += diff
    
    return vector

def f(x):
    return x ** 2

def f_prime(x):
    return 2 * x

start = 10
learn_rate = 0.1
n_iter = 100

minima = gradient_descent(f_prime, start, learn_rate, n_iter)

# %%
minima
# Out:
# 2.0370359763344878e-09

# %% [markdown]
# ### Application of Intergration in ML
#
#
# Integration and definite integrals play a crucial role in machine
# learning, especially in the computation of probabilities and in
# the optimization of functions. For example, the area under the
# curve of a probability density function (PDF) gives the probability of a random variable falling within a certain range. This is
# essential in various machine learning tasks such as classification
# and regression

# %%
import matplotlib.pyplot as plt

def f(x):
    return x**2

# compute integral
x = np.linspace(0, 1, 100)
y = f(x)

integral = np.trapezoid(y, x)
print("Integral:", integral)

# plotting
plt.plot(x, y, 'r')
plt.fill_between(x, y, alpha=0.2)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Integral of f(x) = x^2')

plt.show()
# Out:
# Integral: 0.33335033840084355

# %% [markdown]
# ## Optimization
#
# Optimization involves finding the maximum or minimum of a
# function. In machine learning, we often want to find the minimum of a cost function in order to optimize a model.
#
# Example Consider the cost function J(theta) = (1/2)(h_theta(x)  y)^2
# where h✓(x) is a hypothesis function. To minimize this cost
# function, we can use gradient descent, an optimization algorithm that involves iteratively updating the parameter ✓ in the
# direction of the negative gradient of the cost function

# %% [markdown]
# ## Visualize GD algorithm
#
# In this example, some random data is generated, and then
# the gradient descent algorithm is used to fit a linear model to
# the data. The cost function is plotted to show the convergence
# of the algorithm.

# %%
np.random.seed(0)

X = 2 * np.random.rand(100, 1)
y = 3 + 4 * X + np.random.randn(100,1)

# Add a column of ones to X
X_b = np.c_[np.ones((100, 1)), X]

# compute the normal equation
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# define cost function
def compute_cost(theta, X, y):
    m = len(y)
    cost = (1 / (2 * m)) * np.sum(np.square(X.dot(theta) - y))
    return cost


# define GD function
def gradient_descent(X, y, theta, learning_rate, num_iterations):
    m = len(y)
    cost_history = np.zeros(num_iterations)

    for i in range(num_iterations):

        gradients = (1 / m) * X.T.dot(X.dot(theta) - y)

        theta = theta - learning_rate * gradients

        cost_history[i] = compute_cost(theta, X, y)

    return theta, cost_history

learning_rate = 0.1
num_iterations = 1000

# initialize theta to zero
theta = np.zeros((2,1))

# Run the gradient descent algorithm 
theta, cost_history = gradient_descent(X_b, y, theta, learning_rate, num_iterations)

# plot the cost functions
# Plot the cost function
plt.rcParams["figure.figsize"] = (10, 6)

plt.plot(range(1, num_iterations + 1), cost_history, color='b')

plt.grid()

plt.xlabel('Number of iterations')
plt.ylabel('Cost')
plt.title('Convergence of Gradient Descent')

plt.show()

# %% [markdown]
# ## Backpropagation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the sigmoid activation function and its derivative
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def sigmoid_derivative(x):
    return x * (1 - x)


# Define the dataset and the expected output
inputs = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

expected_output = np.array([
    [0],
    [1],
    [1],
    [0]
])

# Define the parameters of the network
inputLayerNeurons = 2
hiddenLayerNeurons = 2
outputLayerNeurons = 1

# Initialize the weights and biases
hidden_weights = np.random.uniform(
    size=(inputLayerNeurons, hiddenLayerNeurons)
)

hidden_bias = np.random.uniform(
    size=(1, hiddenLayerNeurons)
)

output_weights = np.random.uniform(
    size=(hiddenLayerNeurons, outputLayerNeurons)
)

output_bias = np.random.uniform(
    size=(1, outputLayerNeurons)
)

# Define the learning rate and the number of epochs
learning_rate = 0.1
epochs = 10000

# Train the network
for epoch in range(epochs):

    # Forward pass
    hidden_layer_activation = np.dot(inputs, hidden_weights)
    hidden_layer_activation += hidden_bias

    hidden_layer_output = sigmoid(hidden_layer_activation)

    output_layer_activation = np.dot(
        hidden_layer_output,
        output_weights
    )

    output_layer_activation += output_bias

    predicted_output = sigmoid(output_layer_activation)

    # Compute the error
    error = expected_output - predicted_output

    # Backward pass
    d_predicted_output = (
        error * sigmoid_derivative(predicted_output)
    )

    error_hidden_layer = d_predicted_output.dot(
        output_weights.T
    )

    d_hidden_layer = (
        error_hidden_layer *
        sigmoid_derivative(hidden_layer_output)
    )

    # Update the weights and biases
    output_weights += (
        hidden_layer_output.T.dot(d_predicted_output)
        * learning_rate
    )

    output_bias += (
        np.sum(
            d_predicted_output,
            axis=0,
            keepdims=True
        ) * learning_rate
    )

    hidden_weights += (
        inputs.T.dot(d_hidden_layer)
        * learning_rate
    )

    hidden_bias += (
        np.sum(
            d_hidden_layer,
            axis=0,
            keepdims=True
        ) * learning_rate
    )

# Print predicted output
print("Predicted Output:")
print(predicted_output)

# Plot the predicted output
plt.plot(predicted_output)

plt.xlabel("Input Index")
plt.ylabel("Predicted Output")
plt.title("XOR Neural Network Output")

plt.grid()

plt.show()
# Out:
# Predicted Output:
# [[0.06672317]
#  [0.93776933]
#  [0.9376962 ]
#  [0.06785107]]

# %% [markdown]
# ## Linear Regression model and plotting the result

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some example data
np.random.seed(0)

X = 2 * np.random.rand(100, 1)

y = 3 + 4 * X + np.random.randn(100, 1)

# Add a column of ones to X
X_b = np.c_[np.ones((100, 1)), X]

# Compute the parameters using the normal equation
theta_best = np.linalg.inv(
    X_b.T.dot(X_b)
).dot(X_b.T).dot(y)

# Make predictions
X_new = np.array([
    [0],
    [2]
])

X_new_b = np.c_[np.ones((2, 1)), X_new]

y_predict = X_new_b.dot(theta_best)

# Plot the results
plt.plot(X_new, y_predict, "r-")

plt.plot(X, y, "b.")

plt.axis([0, 2, 0, 15])

plt.xlabel("X")
plt.ylabel("y")

plt.title("Linear Regression using Normal Equation")

plt.grid()

plt.show()

# %%
|
