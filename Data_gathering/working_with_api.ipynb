# %% [markdown]
# API are nothing but data pipelines, make information reach from point A to point B

# %% [markdown]
# Railway reservation:
# * directly from IRCTC
# * MMT
# * ConfirmTkt

# %% [markdown]
# this no. of seat is available : to know this IRCTC makes API available for MMT, ConfirmTkt so that they can extract the data. All these through the api access the same database

# %%
# https://api.themoviedb.org/3/person/popular?api_key=be748cfed5b89310959c567ac3bab2e7

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/person/popular?api_key=')

# %%
# Response [200] : everything fine brother

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'gender': 1,
#    'id': 20652,
#    'known_for_department': 'Acting',
#    'name': 'Cecilia Cheung',
#    'original_name': '張柏芝',
#    'popularity': 54.9037,
#    'profile_path': '/xghVxRPUmFCHYxzD0NxMO8NtoKK.jpg',
#    'known_for': [{'adult': False,
#      'backdrop_path': '/AwlJ2bQGjfEuXLsL5XJAaxOmMuV.jpg',
#      'id': 2008,
#      'title': 'The Promise',
#      'original_title': '无极',
#      'overview': "An orphaned girl, driven by poverty at such a young age, makes a promise with an enchantress. In return for beauty and the admiration of every man, she will never be with the man she loves. This spell cannot be broken unless the impossible happens: snow falling in spring and the dead coming back to life. Now a grown and beautiful princess, she regrets her promise, for all of the men she's loved has always been met with tragedy.",
#      'poster_path': '/tdm4mlc27S1d72ub4Y4xcU2OlDD.jpg',
#      'media_type': 'movie',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'gender': 1,
#   'id': 20652,
#   'known_for_department': 'Acting',
#   'name': 'Cecilia Cheung',
#   'original_name': '張柏芝',
#   'popularity': 54.9037,
#   'profile_path': '/xghVxRPUmFCHYxzD0NxMO8NtoKK.jpg',
#   'known_for': [{'adult': False,
#     'backdrop_path': '/AwlJ2bQGjfEuXLsL5XJAaxOmMuV.jpg',
#     'id': 2008,
#     'title': 'The Promise',
#     'original_title': '无极',
#     'overview': "An orphaned girl, driven by poverty at such a young age, makes a promise with an enchantress. In return for beauty and the admiration of every man, she will never be with the man she loves. This spell cannot be broken unless the impossible happens: snow falling in spring and the dead coming back to life. Now a grown and beautiful princess, she regrets her promise, for all of the men she's loved has always been met with tragedy.",
#     'poster_path': '/tdm4mlc27S1d72ub4Y4xcU2OlDD.jpg',
#     'media_type': 'movie',
#     'original_language': 'zh',
# ...

# %%
pd.DataFrame(response.json()['results']).head()
# Actors popularity
# Out:
#    adult  gender       id known_for_department             name  \
# 0  False       1    20652               Acting   Cecilia Cheung
# 1  False       1  2676077               Acting      Julia Doyle
# 2  False       1   115440               Acting   Sydney Sweeney
# 3  False       1   101652               Acting  Jennifer Runyon
# 4  False       1    34627               Acting      Nadia Farès
#
#      original_name  popularity                      profile_path  \
# 0              張柏芝     54.9037  /xghVxRPUmFCHYxzD0NxMO8NtoKK.jpg
# 1      Julia Doyle     49.7642  /4CtJynpPkV5t7ydwobUUL0sGsTJ.jpg
# 2   Sydney Sweeney     35.6163  /lkEC9xM133h2f8wmp8CpyLr3JNq.jpg
# 3  Jennifer Runyon     28.7331  /1j0Vt7pUROiNvI4ga0KfsNQnlWc.jpg
# 4      Nadia Farès     27.2357  /uvomxwk2CfO8scOsR60CxHGM2J3.jpg
#
#                                            known_for
# 0  [{'adult': False, 'backdrop_path': '/AwlJ2bQGj...
# 1  [{'adult': False, 'backdrop_path': '/auyEi4Xho...
# ...
